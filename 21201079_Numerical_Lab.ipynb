# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def non_linear_func(x):
    return x**3 - 2*x - 5

x = np.linspace(-10, 10, 1000)
y = non_linear_func(x)

plt.plot(x, y)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
def f_primex(x):
  return 3*x**2 - 2

# %%
def arae(x_prev, x_pres): #function of absolute relative approximation error
    return abs((x_pres - x_prev)/x_pres) * 100

def plot(f, f_prime, x0, new_x):
    x = np.linspace(2, 10, 1000)
    y = f(x)

    plt.plot(x, y, 'b', label='f(x)', linewidth=3) #drawing the curve at each iteration
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.axvline(x=new_x, color='g', linestyle='--', label='$x_{i+1}$') #plot the new point of x vertically

    #draw the tangent line for
    x1 = np.linspace(x0-0.05, x0+0.05, 100)
    y1 = f_prime(x0)*(x1-x0) + f(x0) #equation of drawing linear line

    plt.plot(x1, y1, 'r', label='f\'(x)') # drawing the slope at w.r.t the point x0
    plt.axvline(x=x0, color='orange', linestyle='--', label='$x_{i}$')
    plt.scatter(x0, f(x0), color='r') #speicify the point x0,f(x0) in the graph
    plt.grid()
    plt.legend()
    plt.show()


def newton_raphson(f, f_prime, x0, error_tol, max_iter):
    x = x0
    x_prev = None
    error = 1e10
    for i in range(max_iter):
        x = x - f(x)/f_prime(x)
        if x_prev is not None:
            plot(f, f_prime, x_prev, x)
            error = arae(x_prev, x)
            if error < error_tol:
                print("Converged")
                print(f"Error after iteration {i+1}: {error}")
                return x
        x_prev = x
        print(f"Value of x after iteration {i+1}: {x}")
        print(f"Error after iteration {i+1}: {error}")
        print()
    print("here")
    return x

# %%
newton_raphson(non_linear_func, f_primex, 2, 0.01, 100)
# Out:
# Value of x after iteration 1: 2.1
# Error after iteration 1: 10000000000.0
# Value of x after iteration 2: 2.094568121104185
# Error after iteration 2: 0.2593316894821963
# Converged
# Error after iteration 3: 0.0007944137984358022
# 2.094551481698199

# %%
import numpy as np
import matplotlib.pyplot as plt

def non_linear_func(x):
    return x**3 - 2*x - 5

def f_primex(x):
  return 3*x**2 - 2

def arae(x_prev, x_pres):
    return abs((x_pres - x_prev)/x_pres) * 100

def secant_method(f, x0, x1, error_tol, max_iter):
    x_prev = x0
    x = x1
    error = 1e10
    for i in range(max_iter):
        x_next = x - f(x) * ((x - x_prev) / (f(x) - f(x_prev)))
        error = arae(x, x_next)

        print(f"Value of x after iteration {i+1}: {x_next}")
        print(f"Error after iteration {i+1}: {error}")
        print()

        if error < error_tol:
            print("Converged")
            print(f"Error after iteration {i+1}: {error}")
            return x_next

        x_prev = x
        x = x_next
    return x
x0 = 2
x1 = 3
root = secant_method(non_linear_func, x0, x1, 0.01, 100)
print(f"Approximate root: {root}")
# Out:
# Value of x after iteration 1: 2.0588235294117645
# Error after iteration 1: 45.71428571428573
#
# Value of x after iteration 2: 2.081263659845023
# Error after iteration 2: 1.0781973887407128
#
# Value of x after iteration 3: 2.0948241460940524
# Error after iteration 3: 0.6473329169092301
#
# Value of x after iteration 4: 2.0945494310352473
# Error after iteration 4: 0.013115711414334291
#
# Value of x after iteration 5: 2.094551481227599
# Error after iteration 5: 9.788216571722828e-05
#
# Converged
# Error after iteration 5: 9.788216571722828e-05
# Approximate root: 2.094551481227599
